# %% [markdown]
# <a href="https://colab.research.google.com/github/Borikc/Abramov_PI19_1v_19/blob/main/%D0%B3%D1%80%D0%B0%D1%842.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Граф метро - 20 минут по доставке еды, t = [3;7]; t=5

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f3070ac3-1a4d-4382-b43d-1085f3efc9e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3070ac3-1a4d-4382-b43d-1085f3efc9e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('racethetube-moscow.csv')

# %%
data = data.drop(columns='Линия метро')

# %%
data = data.drop(columns=' Линия метро')

# %%
data = data.drop(columns=' Схема метро')

# %%
data = data.drop(columns=' Ссылка на маршрут на карте')

# %%
data = data.drop(columns=' Расстояние')

# %%
data.head()
# Out:
#        Станция отправления         Станция прибытия   Время проезда в метро
# 0             Черкизовская   Преображенская площадь                     145
# 1   Преображенская площадь               Сокольники                     200
# 2               Сокольники           Красносельская                     135
# 3           Красносельская            Комсомольская                     115
# 4            Комсомольская           Красные ворота                     110

# %%
GraphData=data.to_numpy()

# %%
GraphData1 = tuple(map(tuple, GraphData))

# %%
GraphData1
# Out:
# ((' Черкизовская', ' Преображенская площадь', 145),
#  (' Преображенская площадь', ' Сокольники', 200),
#  (' Сокольники', ' Красносельская', 135),
#  (' Красносельская', ' Комсомольская', 115),
#  (' Комсомольская', ' Красные ворота', 110),
#  (' Комсомольская', ' Комсомольская', 360),
#  (' Красные ворота', ' Чистые пруды', 100),
#  (' Чистые пруды', ' Лубянка', 115),
#  (' Чистые пруды', ' Тургеневская', 180),
#  (' Чистые пруды', ' Сретенский бульвар', 180),
#  (' Лубянка', ' Охотный ряд', 100),
#  (' Лубянка', ' Кузнецкий мост', 180),
#  (' Охотный ряд', ' Библиотека имени Ленина', 105),
#  (' Охотный ряд', ' Театральная', 300),
#  (' Библиотека имени Ленина', ' Кропоткинская', 115),
#  (' Библиотека имени Ленина', ' Арбатская', 300),
#  (' Библиотека имени Ленина', ' Александровский сад', 180),
#  (' Библиотека имени Ленина', ' Боровицкая', 360),
#  (' Кропоткинская', ' Парк культуры', 130),
#  (' Парк культуры', ' Фрунзенская', 150),
# ...

# %%
G=nx.Graph()

# %%
G.add_weighted_edges_from('GraphData1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-1eafee3dc4ed> in <module>
# ----> 1 G.add_weighted_edges_from('GraphData1')
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/graph.py in add_weighted_edges_from(self, ebunch_to_add, weight, **attr)
#     986         >>> G.add_weighted_edges_from([(0, 1, 3.0), (1, 2, 7.5)])
#     987         """
# --> 988         self.add_edges_from(((u, v, {weight: d}) for u, v, d in ebunch_to_add), **attr)
#     989
#     990     def remove_edge(self, u, v):
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/graph.py in add_edges_from(self, ebunch_to_add, **attr)
#     931         >>> G.add_edges_from([(3, 4), (1, 4)], label="WN2898")
#     932         """
# --> 933         for e in ebunch_to_add:
#     934             ne = len(e)
#     935             if ne == 3:
#
# ...
